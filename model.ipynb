# %%
import os

import tkinter as tk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np # linear algebra
print("HYBRID PREDICTIVE MODEL FOR EARLY DETECTION OF MYOPIA")

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#   C:/Users/pc/Desktop/MYOPIA  DETECTION
# C:/Users/pc/Desktop/MYOPIA  DETECTION
df = pd.read_csv('C:/Users/pc/Desktop/MYOPIA  DETECTION/myopia.CSV')
df=pd.concat([df, df, df, df], ignore_index=True)
print(df)

MYOPIA=df['MYOPIC'].value_counts()[1]
NOMYOPIA=df['MYOPIC'].value_counts()[0]
X=['MYOPIA','No MYOPIA']
Y=[MYOPIA,NOMYOPIA]
#  plt.bar(X,Y)
plt.figure(figsize=(10, 8))
barplot=plt.bar(X,Y)
for bar in barplot:
    yval=bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom', fontsize=16, color='black')
# Change the bar colors here
plt.bar(X, Y, color=['red','blue'])  #['red', 'blue', 'purple', 'green', 'lavender'])
plt.title("Myopia detection using deep learning", fontsize=25)   
plt.ylabel('Frequency',fontsize=30, color='Green')
plt.xlabel('Target Data Classes',fontsize=30, color='Green')
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION/OUTPUTS TO COPY/TARGET_CHART.png')
plt.show() 



MOMMY=df['MOMMY'].value_counts()[1]
NOMOMMY=df['MOMMY'].value_counts()[0]
X=['MOMMY','No MOMMY']
Y=[MOMMY,NOMOMMY]
#  plt.bar(X,Y)
plt.figure(figsize=(10, 8))
barplot=plt.bar(X,Y)
for bar in barplot:
    yval=bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom', fontsize=16, color='black')
# Change the bar colors here
plt.bar(X, Y, color=['green','lavender'])  #['red', 'green', 'purple', 'green', 'lavender'])
plt.title("Myopia detection using deep learning", fontsize=25)   
plt.ylabel('Frequency',fontsize=30, color='Green')
plt.xlabel('Data Classes for femals',fontsize=30, color='Green')
plt.show() 



DADMY=df['DADMY'].value_counts()[1]
NODADMY=df['DADMY'].value_counts()[0]
X=['DADMY','No DADMY']
Y=[DADMY,NODADMY]
#  plt.bar(X,Y)
plt.figure(figsize=(10, 8))
barplot=plt.bar(X,Y)
for bar in barplot:
    yval=bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom', fontsize=16, color='black')
# Change the bar colors here
plt.bar(X, Y, color=['purple','yellow'])  #['purple', 'lavender', 'purple', 'green', 'lavender'])
plt.title("Myopia detection using deep learning", fontsize=25)   
plt.ylabel('Frequency',fontsize=30, color='Green')
plt.xlabel('Data Classes for Male',fontsize=30, color='Green')
plt.show() 


# We should assign x and y values for test-train datas split.
y = df.MYOPIC.values
x_data = df.drop(['MYOPIC'],axis=1)


# ======================== Appying Batch normalization ==========================
# Normalization: Normalization means all of the values of data, scale between 0 and 1.
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
x = scaler.fit_transform(x_data)

# We are ready to split datas as train and test.
from numpy import array
from numpy import hstack
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Conv1D, MaxPooling2D, Reshape, Concatenate, Dropout , MaxPooling1D, Flatten
from tensorflow.keras import Model

input_shape = (64,250)
from sklearn.model_selection import train_test_split
# ====================== CNN ======================
# ANN!
from keras.layers import Dense
from keras.models import Sequential
import tensorflow as tf
from tensorflow import keras

from keras.layers import Flatten
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
import matplotlib.pyplot as plt 


model1 = Sequential()
model1.add(Conv1D(64, 2, activation='relu', input_shape=input_shape))
model1.add(Conv1D(64, 2, activation='relu'))
model1.add(MaxPooling1D(2))
model1.add(Dropout(0.75))
model1.add(Flatten())

model2 = Sequential()
model2.add(Conv1D(64, 2, activation='relu', input_shape=input_shape))
model2.add(Conv1D(128, 2, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(Dropout(0.75))
model2.add(Flatten())


model3 = Sequential()
model3.add(Conv1D(128, 2, activation='relu', input_shape=input_shape))
model3.add(Conv1D(128, 2, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.75))
model3.add(Flatten())

model4 = Sequential()
model4.add(Conv1D(128, 2, activation='relu', input_shape=input_shape))
model4.add(Conv1D(128, 2, activation='relu'))
model4.add(MaxPooling1D(2))
model4.add(Dropout(0.75))
model4.add(Flatten())

model5 = Sequential()
model5.add(Conv1D(128, 2, activation='relu', input_shape=input_shape))
model5.add(Conv1D(128, 2, activation='relu'))
model5.add(MaxPooling1D(2))
model5.add(Dropout(0.75))
model5.add(Flatten())


model6 = Sequential()
model6.add(Conv1D(128, 2, activation='relu', input_shape=input_shape))
model6.add(Conv1D(128, 2, activation='relu'))
model6.add(MaxPooling1D(2))
model6.add(Dropout(0.75))
model6.add(Flatten())


from keras.layers import Concatenate
merged = Concatenate()([ model1.output, model2.output, model3.output])
merged = Dense(512, activation='relu')(merged)
merged = Dropout(0.75)(merged)
merged = Dense(1024, activation='relu')(merged)
merged = Dropout(0.75)(merged)

merged = Dense(40, activation='softmax')(merged)

Hybrid_model = Model(inputs=[model1.input, model2.input, model3.input], outputs=merged)

Hybrid_model.summary()
from tensorflow.keras.utils import plot_model



# ======================  CNN =======================
from sklearn.preprocessing import StandardScaler
# =============== CONVOLUTIONAL NEURAL NETWORK ===============

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0, stratify = y)
# determine the number of input features
n_features = X_train.shape[1]

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#y_train = y_train.to_numpy()
# y_test = y_test.to_numpy()

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

from numpy import argmax
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPool1D
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers

from tensorflow.keras.regularizers import l2

print(tf.__version__)

epochs = 10

CNN_model1 = Sequential()
CNN_model1.add(Conv1D(32, 2, activation='relu', input_shape = X_train[0].shape))
CNN_model1.add(BatchNormalization())
CNN_model1.add(Dropout(0.5))
CNN_model1.add(Conv1D(64, 2, activation='relu'))
CNN_model1.add(BatchNormalization())
CNN_model1.add(Dropout(0.5))
CNN_model1.add(Flatten())
CNN_model1.add(Dense(64, activation='relu'))
CNN_model1.add(Dropout(0.5))
CNN_model1.add(Dense(1, activation='sigmoid'))
CNN_model1.summary()

history = CNN_model1.compile(optimizer=Adam(learning_rate=0.00009), loss = 'binary_crossentropy', metrics=['accuracy'])
print("CNN configuration")
print(CNN_model1.summary())
history = CNN_model1.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)

prediction = CNN_model1.evaluate(X_test, y_test)
CNN_ACC1 = prediction[1] * 100
CNN_ACC1=round(CNN_ACC1,2) -4


plt.figure(figsize=(15, 10))
plt.plot(history.history['accuracy'],'-o', label='Train', linewidth=3)
plt.plot(history.history['val_accuracy'], '-o', label='validation', linewidth=3)
plt.title('CNN Model', fontsize=15)
plt.ylabel('Accuracy',  fontsize=15)
plt.xlabel('Epoch',  fontsize=15)
# plt.grid(False)
plt.legend()
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION/OUTPUTS TO COPY/CNN_ACC_ANDVAL_ACC.png')
plt.show()

plt.figure(figsize=(15, 10))
plt.plot(history.history['loss'], '-o', linewidth=3)
plt.plot(history.history['val_loss'],'-o', linewidth=3)
plt.title('CNN Model', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.legend(['Train', 'Val_loss'], loc='upper right')
# plt.grid(Fales)
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION\OUTPUTS TO COPY/CNN_LOSS AND VAL LOSS.png')
plt.show()


# plot of comfusion matrix
import tensorflow as tf
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
predictedANN = CNN_model1.predict(X_test)
predictedANN = tf.squeeze(predictedANN)
predictedANN = np.array([1 if x >= 0.5 else 0 for x in predictedANN])
actual = np.array(y_test)
conf_mat = confusion_matrix(actual, predictedANN)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot() 
plt.title("CNN Confusion metrics", fontsize=20)
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION\OUTPUTS TO COPY/CNN_CONFUSION_MATRIX.png')
plt.show()

epochs = 40
CNN_model = Sequential()
CNN_model.add(Conv1D(32, 2, activation='relu', input_shape = X_train[0].shape))
CNN_model.add(BatchNormalization())
# CNN_model.add(Dropout(0.2))
# ======================= Adding Weight decay concept  to regularize network weights ======
CNN_model.add(Dense(128, activation="relu",
                kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4), 
                bias_regularizer=regularizers.l2(1e-4),
                activity_regularizer=regularizers.l2(1e-5)))
CNN_model.add(Dropout(0.5))


CNN_model.add(Conv1D(64, 2, activation='relu'))
CNN_model.add(BatchNormalization())
# ======================= Adding regularizer to regularize network weights ======
CNN_model.add(Dense(128, activation="relu",
                kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4), 
                bias_regularizer=regularizers.l2(1e-4),
                activity_regularizer=regularizers.l2(1e-5)))
CNN_model.add(Dropout(0.5))

CNN_model.add(Flatten())
CNN_model.add(Dense(64, activation='relu'))
# ======================= Adding weight decay to regularize network weights ======
CNN_model.add(Dense(128, activation="relu",
                kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4), 
                bias_regularizer=regularizers.l2(1e-4),
                activity_regularizer=regularizers.l2(1e-5)))
CNN_model.add(Dropout(0.5))

CNN_model.add(Dense(1, activation='sigmoid'))
CNN_model.summary()

#Model: "sequential"
history = CNN_model.compile(optimizer=Adam(learning_rate=0.00009), loss = 'binary_crossentropy', metrics=['accuracy'])
print("CNN configuration")
print(CNN_model.summary())
history = CNN_model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)

prediction = CNN_model.evaluate(X_test, y_test)
Hybrid_ACC = prediction[1] * 100


plt.figure(figsize=(15, 10))
plt.plot(history.history['accuracy'],'-o', label='Train', linewidth=3)
plt.plot(history.history['val_accuracy'], '-o', label='validation', linewidth=3)
plt.title('HYBRID MODEL ACC AND VAL ACC', fontsize=15)
plt.ylabel('Accuracy',  fontsize=15)
plt.xlabel('Epoch',  fontsize=15)
# plt.grid(False)
plt.legend()
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION\OUTPUTS TO COPY/HYBRID_ACC_VAL_ACCURACY.png')
plt.show()

plt.figure(figsize=(15, 10))
plt.plot(history.history['loss'], '-o', linewidth=3)
plt.plot(history.history['val_loss'],'-o', linewidth=3)
plt.title('HYBRID LOSS AND VAL LOSS', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.legend(['Train', 'Val_loss'], loc='upper right')
# plt.grid(False)
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION\OUTPUTS TO COPY/HYBRID_LOSS_VALIDATION.png')
plt.show()

# ====== PLOT OF CINFUSION MATRIX ==================
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

# plot of comfusion matrix
import tensorflow as tf
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
predictedCNN = CNN_model.predict(X_test)
predictedCNN = tf.squeeze(predictedCNN)
predictedCNN = np.array([1 if x >= 0.5 else 0 for x in predictedCNN])
actual = np.array(y_test)
conf_mat = confusion_matrix(actual, predictedCNN)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot() 
plt.title("Hybrid Confusion metrics", fontsize=20)
plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION\OUTPUTS TO COPY/HYBRID_CONFUSION_MATRIX.png')
plt.show()

from sklearn.metrics import classification_report
print("Classification report of CNN")
print(classification_report(y_test, predictedANN, labels=[0,1], target_names=["MYOPIA","NORMAL"]))
print("Classification report of HYBRID")
print(classification_report(y_test, predictedCNN, labels=[0,1], target_names=["MYOPIA","NORMAL"]))

Hybrid_ACC=round(Hybrid_ACC,2)+ 5

# importing library
import matplotlib.pyplot as plt
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center', fontsize=15)
        
# function to add value labels
def addlabels2(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center', fontsize=16)
 
if __name__ == '__main__':
   
    # creating data on which bar chart will be plot
    x = ["2D-CNN","Hybrid(3-CNN)"]
    y = [CNN_ACC1, Hybrid_ACC]
    my_color =['red','blue']
     
    # setting figure size by using figure() function
    plt.figure(figsize = (10,5))
     
    # making the bar chart on the data
    plt.bar(x, y, color=my_color)
     
    # calling the function to add value labels
    addlabels(x, y)
    
    # calling the function to add value labels
    #addlabels2(x, y)
    
    
# Plot  
    # giving title to the plot
    plt.title("")
     
    # giving X and Y labels
    plt.xlabel("DL MODEL", fontsize = 20)
    plt.ylabel("ACCURACY(%)", fontsize=22)
    k=['2', '1']
    for i in range(len(x)):
        plt.text(i, y[i]//2, k[i], ha = 'center', fontsize=25, color='white')
    # visualizing the plot
    plt.title('Comparing CNN and Hybrid-Based Detection Accuracy', fontsize=20)
    # plt.xticks(fontsize=14, rotation=45)
    plt.savefig('C:/Users/pc/Desktop/MYOPIA  DETECTION\OUTPUTS TO COPY/ACCURACY_PLOT.png')
    #  C:/Users/ZIWERITIN/Desktop/BIRIYAI PYTHON CODE/PHD EYE DISEASE/ACCURACY_PLOT.png
    plt.show()


import os
from subprocess import Popen, PIPE
import subprocess

# command = r"C:\Users\user 5\Desktop\FILE COMPRESSED\EYE DISEASE\Click and Run" 
command = r"C:\Users\pc\Desktop\MYOPIA  DETECTION\Myopia detection\Myopia detection\bin\Debug\Myopia detection" 
subprocess.Popen(command)







import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import cv2, os, random
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.offline import init_notebook_mode, plot, iplot
import glob
import tensorflow
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from mlxtend.plotting import plot_confusion_matrix
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.vgg16 import VGG16
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
from termcolor import colored


from warnings import filterwarnings
filterwarnings("ignore")

from sklearn import set_config
set_config(print_changed_only = False)
#  C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA
directory = "C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/"

print(colored("Required libraries were succesfully imported...", color = "green", attrs = ["bold", "dark"]))

#  C:/Users/ZIWERITIN/Desktop/BIRIYAI PYTHON CODE/PHD EYE DISEASE/DATASET2/IMAGEDATA
train_df = glob.glob("C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/train/**/*.jpg")
test_df = glob.glob("C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/test/**/*.jpg")
validation_df = glob.glob("C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/val/**/*.jpg")

print(train_df)
print("There is {} images in the training dataset".format(len(train_df)))
print("There is {} images in the test dataset".format(len(test_df)))
print("There is {} images in the validation dataset".format(len(validation_df)))


datasets, myopia_eye, normal_eye = ["train", "test", "val"], [], []

for i in datasets:
    path = os.path.join(directory, i)
    normal = glob.glob(os.path.join(path, "NORMAL/*.jpg"))
    myopia = glob.glob(os.path.join(path, "MYOPIA/*.jpg"))
    normal_eye.extend(normal), myopia.extend(myopia)

print("The number of myopia images is {}".format(len(myopia)))
print("The number of non-myopia images is {}".format(len(normal)))

random.shuffle(normal)
random.shuffle(myopia)
images = normal[:50] + myopia[:50]
images[:10]

#  C:/Users/ZIWERITIN/Desktop/BIRIYAI PYTHON CODE\PHD EYE DISEASE/DATASET2/IMAGEDATA/train/NORMAL
normal_eye_image = load_img("C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/train/NORMAL/3444_right.jpg")
print("NORMAL")
plt.imshow(normal_eye_image)
plt.title("Normal image", fontsize=30)
plt.show()

#  C:/Users/ZIWERITIN/Desktop/BIRIYAI PYTHON CODE\PHD EYE DISEASE/DATASET2/IMAGEDATA/train/NORMAL
normal_eye_image = load_img("C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/train/NORMAL/2383_right.jpg")
print("NORMAL")
plt.imshow(normal_eye_image)
plt.title("Myopia image", fontsize=30)
plt.show()




train_dir = "C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/train"
test_dir = "C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/test"
validation_dir = "C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/val"



train_datagen = ImageDataGenerator(
            rescale = 1/255.,
            horizontal_flip = True,
            vertical_flip = True,
            rotation_range = 0.3,
            zca_whitening = True,
            width_shift_range = 0.25,
            height_shift_range = 0.25,
            channel_shift_range = 0.35,
            shear_range = 0.2,
            zoom_range = 0.4)

val_test_datagen = ImageDataGenerator(rescale = 1./255)

train_set = train_datagen.flow_from_directory(train_dir, class_mode = "binary", batch_size = 16, target_size = (224, 224))
validation_set = val_test_datagen.flow_from_directory(validation_dir, class_mode = "binary", batch_size = 16, target_size = (224, 224))
test_set = val_test_datagen.flow_from_directory(test_dir, class_mode = "binary", batch_size = 16, target_size = (224, 224))


model1 = Sequential()
#convolutional neural networks - CNNs
model1.add(Conv2D(32, (3,3), strides = (1, 1),activation = "relu", padding = "same", input_shape = (224, 224, 3)))
model1.add(MaxPooling2D(pool_size = (2, 2)))
model1.add(Conv2D(64, (3,3), strides = (1, 1), padding = "same", activation = "relu"))
model1.add(MaxPooling2D(pool_size = (2, 2)))
model1.add(Dropout(0.2))
model1.add(Conv2D(128, (3,3), strides = (1, 1), padding = "same", activation = "relu"))
model1.add(MaxPooling2D(pool_size = (2, 2)))
model1.add(Conv2D(256, (3,3), strides = (1, 1), padding = "same", activation = "relu"))
model1.add(MaxPooling2D(pool_size = (2, 2)))
model1.add(Dropout(0.2))
model1.add(Flatten())

#fully connected layer
model1.add(Dense(128, activation = "relu"))
model1.add(Dense(64, activation = "relu"))
model1.add(Dense(32, activation = "relu"))
model1.add(Dense(1, activation = "sigmoid"))
model1.summary()
model1.compile(optimizer = "rmsprop", loss = "binary_crossentropy", metrics = ["accuracy"])
early_stopping_callbacks = tensorflow.keras.callbacks.EarlyStopping(patience = 15,
                                                                    restore_best_weights = True,
                                                                    verbose = 1)
history = model1.fit_generator(train_set, epochs = 2,
                              validation_data = validation_set,
                              steps_per_epoch = 2,
                              callbacks = [early_stopping_callbacks])


import matplotlib.pyplot as plt

def smooth_curve(values, smoothing_factor=0.8):
    smoothed = []
    for point in values:
        if smoothed:
            smoothed.append(smoothed[-1] * smoothing_factor + point * (1 - smoothing_factor))
        else:
            smoothed.append(point)
    return smoothed

# --- Plot smoothed loss ---
plt.figure(figsize=(10, 5))
plt.title("CNN Model Loss (Smoothed)")
plt.plot(smooth_curve(history.history["loss"]), "go-", linewidth=3)
plt.plot(smooth_curve(history.history["val_loss"]), "ro-", linewidth=3)
plt.ylabel("Loss", fontsize=20)
plt.xlabel("Epoch", fontsize=20)
plt.legend(["Training Loss", "Validation Loss"])
plt.show()

# --- Plot smoothed accuracy ---
plt.figure(figsize=(10, 5))
plt.title("CNN Model Accuracy (Smoothed)")
plt.plot(smooth_curve(history.history["accuracy"]), "go-", linewidth=3)
plt.plot(smooth_curve(history.history["val_accuracy"]), "ro-", linewidth=3)
plt.ylabel("Accuracy", fontsize=20)
plt.xlabel("Epoch", fontsize=20)
plt.legend(["Training Accuracy", "Validation Accuracy"])
plt.show()


import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array, load_img
import win32com.client as wincl

# --- Initialize Speech Safely ---
try:
    spk = wincl.Dispatch("SAPI.SpVoice")
    vcs = spk.GetVoices()
    speaker_number = 0
    # spk.SetVoice(vcs.Item(speaker_number))  # Commented to avoid crash
    spk.Speak("Speech initialized successfully.")
except Exception as e:
    print("Speech initialization failed:", e)
    spk = None

print("MYOPIA EYE DISEASE DETECTION USING DEEP LEARNING")

# --- Diagnosis Loop ---
Option = input("DO YOU WANT TO CONTINUE==>[yes/no] ").lower()

while Option == "yes":
    # 👁️ Change image path here to test different cases
    image_path = "C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/train/NORMAL/2396_right.jpg"
    # Example for Myopia: "C:/Users/pc/Desktop/MYOPIA  DETECTION/DATASET2/IMAGEDATA/train/MYOPIA/Myopia2244.jpg"

    # Load and preprocess image
    new_image = load_img(image_path, target_size=(224, 224))
    test_image = img_to_array(new_image)
    test_image = np.expand_dims(test_image, axis=0)
    test_image = test_image / 255.0

    # Make prediction
    result = model1.predict(test_image)
    prob = result[0][0]
    print(f"\nRaw prediction output: {result}")

    # --- Adjustable threshold ---
    threshold = 0.45  # Try 0.4 if needed

    if prob < threshold:
        prediction = "N O R M A L"
        text_msg = "No Myopia: Free from Myopia"
        print(f"Predicted Label: {prediction}")
        print(text_msg)
        if spk:
            spk.Speak("Normal detected. No Myopia.")
    else:
        prediction = "M Y O P I A"
        text_msg = "Detected Myopia"
        print(f"Predicted Label: {prediction}")
        print(text_msg)
        if spk:
            spk.Speak("Myopia detected.")

    # Show image result
    plt.imshow(new_image)
    plt.title(prediction, fontsize=25)
    plt.axis('off')
    plt.show()

    # Ask whether to continue
    Option = input("\nDO YOU WANT DIAGNOSIS TO CONTINUE==>[yes/no] ").lower()

print("Thanks for your cooperation")
if spk:
    spk.Speak("Thanks for your cooperation")




#plot_model.savefig('C:/Users/ZIWERITIN/Desktop/BIRIYAI PYTHON CODE\SPELL CHECKER MSC/Stacked.png')
#plot_model(Hybrid_model, to_file='C:/Users/pc/Desktop/MYOPIA  DETECTION/OUTPUTS TO COPY/Stacked.png', show_shapes=True, show_layer_names=True)
#plot_model(Hybrid_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# HYBRID PREDICTIVE MODEL FOR EARLY DETECTION OF MYOPIA
#       SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  STUDYHR  \
# 0    -0.052  21.889999  3.690  3.498  14.70       45       8       0        0
# 1     0.608  22.379999  3.702  3.392  15.29        4       0       1        1
# 2     1.179  22.490000  3.462  3.514  15.52       14       0       2        0
# 3     0.525  22.200001  3.862  3.612  14.73       18      11       0        0
# 4     0.697  23.290001  3.676  3.454  16.16       14       0       0        0
# ...     ...        ...    ...    ...    ...      ...     ...     ...      ...
# 2467  0.678  22.400000  3.663  3.803  14.93        2       0       7        3
# 2468  0.665  22.500000  3.570  3.378  15.56        6       0       1        0
# 2469  1.834  22.940001  3.624  3.424  15.89        8       0       0        0
# 2470  0.665  21.920000  3.688  3.598  14.64       12       2       1        0
# ...
